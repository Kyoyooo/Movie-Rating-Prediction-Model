# %% [markdown]
# # Movie Rating Prediction Model

# %% [markdown]
# ## Khám phá dữ liệu phục vụ cho việc tiền xử lý

# %% [markdown]
# ### Import các thư viện

# %%
import numpy as np
import pandas as pd

# %%
# !pwd
# Out:
# /home/duyhoang/Downloads/TH NMKHDL/IMDB /notebooks

# %% [markdown]
# ### Load vào dữ liệu thô

# %%
file_path = "../data/raw/IMDB_movies_final.csv"
df = pd.read_csv(file_path)
df
# Out:
#         rank                                title  \
# 0          1                         Frankenstein
# 1          2             One Battle After Another
# 2          3                      The Running Man
# 3          4                   Predator: Badlands
# 4          5                             Playdate
# ...      ...                                  ...
# 10043  10046        Return of the Living Dead III
# 10044  10047                            Sweetness
# 10045  10048                         Dark Harvest
# 10046  10049  Across the River and Into the Trees
# 10047  10050                                Below
#
#                                     genres                    budget  \
# 0           Drama, Fantasy, Horror, Sci-Fi  $120,000,000 (estimated)
# 1           Action, Crime, Drama, Thriller  $130,000,000 (estimated)
# 2      Action, Adventure, Sci-Fi, Thriller  $110,000,000 (estimated)
# 3      Action, Adventure, Sci-Fi, Thriller  $105,000,000 (estimated)
# 4                           Action, Comedy                   $17,525
# ...                                    ...                       ...
# 10043                               Horror    $2,000,000 (estimated)
# 10044                             Thriller                       NaN
# 10045                      Fantasy, Horror                       NaN
# 10046                  Drama, Romance, War                       NaN
# 10047    Action, Horror, Mystery, Thriller   $40,000,000 (estimated)
#
#        release_year run_time    mpa  metascore vote_count  rating
# 0            2025.0   2h 29m      R       77.0     (132K)     7.6
# 1            2025.0   2h 41m      R       95.0     (163K)     8.0
# 2            2025.0   2h 13m      R       56.0      (17K)     6.7
# 3            2025.0   1h 47m  PG-13       71.0      (38K)     7.5
# 4            2025.0   1h 33m  PG-13       20.0      (10K)     5.5
# ...             ...      ...    ...        ...        ...     ...
# 10043        1993.0   1h 37m    NaN       47.0      (18K)     5.9
# 10044        2025.0   1h 33m    NaN        NaN       (81)     6.8
# 10045        2023.0   1h 36m      R       51.0      (10K)     5.5
# 10046        2022.0   1h 46m    NaN       63.0       (1K)     6.6
# 10047        2002.0   1h 45m      R       55.0      (26K)     6.1
#
# [10048 rows x 10 columns]
